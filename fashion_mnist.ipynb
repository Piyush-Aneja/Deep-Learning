# %%
# %config IPCompleter.greedy=True
import matplotlib.pyplot as plt

# %%
import numpy as np
from keras.layers import Dense,Flatten
from keras.models import Sequential

# %% [markdown]
# import tensorflow as tf

# %% [raw]
# from tf import keras

# %%
from keras.datasets import fashion_mnist

# %%
(X_train,train_label),(X_test,test_label)=fashion_mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
fig=plt.imshow(X_train[0])
plt.colorbar()
plt.gray()

# %%
class_names=['Tshirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
X_train=X_train/255.0

# %%
X_test=X_test/255.0

# %%
train_label.shape
# Out:
# (60000,)

# %%
test_label.shape
# Out:
# (10000,)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_train[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[train_label[i]])

# %%
model=Sequential()

# %%
model.add(Flatten(input_shape=(28,28)))

# %%
model.add(Dense(128,activation='relu'))

# %%
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,train_label, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.5015 - accuracy: 0.8232
# Epoch 2/5
# 60000/60000 [==============================] - 8s 140us/step - loss: 0.3733 - accuracy: 0.8634
# Epoch 3/5
# 60000/60000 [==============================] - 8s 140us/step - loss: 0.3351 - accuracy: 0.8783
# Epoch 4/5
# 60000/60000 [==============================] - 8s 140us/step - loss: 0.3128 - accuracy: 0.8853
# Epoch 5/5
# 60000/60000 [==============================] - 8s 140us/step - loss: 0.2933 - accuracy: 0.8922

# %%
test_loss,test_acc=model.evaluate(X_test,test_label)
# Out:
# 10000/10000 [==============================] - 1s 60us/step

# %%
print("test acc=",test_acc)
# Out:
# test acc= 0.8791000247001648

# %%
X_test.shape
#Y_test.shape
# Out:
# (10000, 28, 28)

# %%
pred=model.predict(X_test)

# %% [markdown]
# print("Number between 0 to 10000 to check the model predictions->")

# %%
check=int(input("Enter no->"))
# Out:
# Enter no->1

# %%
print("Model predicted below image as-> " ,class_names[np.argmax(pred[check])])
plt.imshow(X_test[check])
plt.colorbar()
plt.xlabel(class_names[test_label[check]])
plt.show()
# Out:
# Model predicted below image as->  Pullover
